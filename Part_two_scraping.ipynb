# %%
from bs4 import BeautifulSoup
import requests

response = requests.get("https://www.lemonde.fr/en/")
doc = BeautifulSoup(response.text)

# %%
items = doc.find_all(class_ = 'article')

#empty list
rows = []
for item in items:
    
    #empty dictionary
    row = {}
    #To get article title
    row['Title'] = item.select_one('.article__title').text.strip()
    #To get article image
    row['Image'] = item.find('img').get('data-src') or item.find('img').get('src') if item.find('img') else "No image"
    #To get article link
    row['URL'] = item.select_one('a.lmd-link-clickarea__link').get('href') if item.select_one('a.lmd-link-clickarea__link') else "No url"
    #To get article credit
    row['Byline'] = item.select_one('.article__media-credit').text.strip() if item.select_one('.article__media-credit') else "No credit"
    #To get article subtitle
    row['Subtitle'] = item.select_one('.article__desc').text.strip() if item.select_one('.article__desc') else "No subtitle"
    #To get subscriber/free stories
    row['Access'] = item.find(class_="sr-only").text.strip() if item.find(class_="sr-only") else "Free to read"
    #Article type: class="article__kicker">Editorial</div>
    row['Type'] = item.find(class_="article__kicker").text.strip() if item.find(class_="article__kicker") else "Type not labeled"


    rows.append(row)

# %%
import pandas as pd

df = pd.json_normalize(rows)
df
# Out:
#                                                 Title  \
# 0   The American GBU-57 bomb is the only weapon ca...
# 1               Sweden sounds the alarm on loneliness
# 2   At the heart of the Arctic, the 'Noah's Ark fo...
# 3   Despite the killing of top brass, Iran's milit...
# 4   EU lawmakers seek to end statute of limitation...
# 5   Criticism is mounting in the Netherlands again...
# 6   Five years after Brexit, UK and EU aim for a f...
# 7   In Lithuania, the fear of war with Russia lurk...
# 8   French police launch nationwide crackdown on u...
# 9   Tolerance holding up in France despite hate sp...
# 10  From Chenonceau to the Acropolis, heritage sit...
# 11  Beloved black Corsican beaches threatened by n...
# 12  What is France's 'Black code' and why hasn't i...
# 13                How was the European Union created?
# 14  Glide bombs: Russia's secret to making cheap w...
# 15           How does the conclave pick the new pope?
# 16  'Iran's nuclear obsession could lead to endles...
# 17       Age-based employment discrimination must end
# 18  Why Paris's Centre Pompidou, not even 50 years...
# 19  'For the Iranian that I am, nothing justifies ...
# 20           Wolfgang Tillmans' photography in action
# 21  On the Canadian side of lake Ontario, a new id...
# 22  Kazakhstan families search for clues about the...
# 23    Maria Grazia Chiuri's final bow at home in Rome
# 24  Why Paris's Centre Pompidou, not even 50 years...
# 25  Paris exhibition tries to answer the mystery o...
# 26  Forget the jambon-beurre, try these five delic...
# 27  Gabriele Münter, a framing prodigy, emerges fr...
# 28  How Trump broke with his strategic allies to s...
# 29  The American GBU-57 bomb is the only weapon ca...
# 30  French police launch nationwide crackdown on u...
# 31              Sweden sounds the alarm on loneliness
# 32  Chinese cities are facing the financial abyss ...
# 33           Wolfgang Tillmans' photography in action
# 34  Despite the killing of top brass, Iran's milit...
# 35  Second woman accuses French senator Guerriau o...
# 36  Israel army says struck weapons research cente...
# 37  Who is Gonjeshke Darande, the group behind the...
# 38  'Early' heatwave with temperatures reaching 38...
# 39  Trump delays TikTok ban again, grants app 90-d...
# 40  Violence against children in war zones hits re...
# 41  After French school supervisor stabbing, quest...
# 42    Free the knees! A plea for shorts at the office
# 43      Why the French economy is stuck in stagnation
# 44  Swiss police raid on financial blogger reignit...
# 45  Outspoken Nicaraguan opposition figure Roberto...
# 46              French MP banned from entering the US
# 47  Limiting global warming to 1.5°C is now imposs...
# 48  War in Ukraine has been a social elevator for ...
# 49  Why Paris's Centre Pompidou, not even 50 years...
# 50  'Iran's nuclear obsession could lead to endles...
# 51  'For the Iranian that I am, nothing justifies ...
# 52       Age-based employment discrimination must end
#
#                                                 Image  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28  https://img.lemde.fr/2025/06/19/64/0/5402/3601...
# 29  https://img.lemde.fr/2025/06/17/0/219/1609/107...
# 30  https://img.lemde.fr/2025/06/19/0/0/7942/5294/...
# 31  https://img.lemde.fr/2025/06/17/0/0/3499/2333/...
# 32  https://img.lemde.fr/2025/06/09/0/0/6000/4000/...
# 33  https://img.lemde.fr/2025/05/20/312/0/1000/666...
# 34  https://img.lemde.fr/2025/06/19/0/0/4813/3208/...
# 35  https://img.lemde.fr/2025/06/20/1/0/8192/5461/...
# 36  https://img.lemde.fr/2025/06/19/0/0/2194/1463/...
# 37  https://img.lemde.fr/2025/06/17/0/441/1800/120...
# 38  https://img.lemde.fr/2025/06/13/0/0/6000/4000/...
# 39                                           No image
# 40                                           No image
# 41                                           No image
# 42                                           No image
# 43                                           No image
# 44                                           No image
# 45                                           No image
# 46                                           No image
# 47  https://img.lemde.fr/2025/06/18/0/0/3993/2662/...
# 48  https://img.lemde.fr/2025/06/18/1667/0/4000/26...
# 49  https://img.lemde.fr/2025/03/09/0/0/7801/5200/...
# 50  https://img.lemde.fr/2025/02/13/0/0/0/0/100/10...
# 51                                           No image
# 52                                           No image
#
#                                                   URL  \
# 0                                              No url
# 1                                              No url
# 2                                              No url
# 3                                              No url
# 4                                              No url
# 5                                              No url
# 6                                              No url
# 7                                              No url
# 8                                              No url
# 9                                              No url
# 10                                             No url
# 11                                             No url
# 12                                             No url
# 13                                             No url
# 14                                             No url
# 15                                             No url
# 16                                             No url
# 17                                             No url
# 18                                             No url
# 19                                             No url
# 20                                             No url
# 21                                             No url
# 22                                             No url
# 23                                             No url
# 24                                             No url
# 25                                             No url
# 26                                             No url
# 27                                             No url
# 28  https://www.lemonde.fr/en/history/article/2025...
# 29  https://www.lemonde.fr/en/international/articl...
# 30  https://www.lemonde.fr/en/france/article/2025/...
# 31  https://www.lemonde.fr/en/international/articl...
# 32  https://www.lemonde.fr/en/economy/article/2025...
# 33  https://www.lemonde.fr/en/m-le-mag/article/202...
# 34                                             No url
# 35  https://www.lemonde.fr/en/france/article/2025/...
# 36  https://www.lemonde.fr/en/international/articl...
# 37  https://www.lemonde.fr/en/pixels/article/2025/...
# 38  https://www.lemonde.fr/en/environment/article/...
# 39  https://www.lemonde.fr/en/pixels/article/2025/...
# 40  https://www.lemonde.fr/en/global-issues/articl...
# 41  https://www.lemonde.fr/en/pixels/article/2025/...
# 42  https://www.lemonde.fr/en/our-times/article/20...
# 43  https://www.lemonde.fr/en/economy/article/2025...
# 44  https://www.lemonde.fr/en/economy/article/2025...
# 45  https://www.lemonde.fr/en/international/articl...
# 46  https://www.lemonde.fr/en/international/articl...
# 47                                             No url
# 48                                             No url
# 49                                             No url
# 50                                             No url
# 51                                             No url
# 52                                             No url
#
#                                                Byline  \
# 0                                           No credit
# 1                                           No credit
# 2                                           No credit
# 3                                           No credit
# 4                                           No credit
# 5                                           No credit
# 6                                           No credit
# 7                                           No credit
# 8                                           No credit
# 9                                           No credit
# 10                                          No credit
# 11                                          No credit
# 12                                          No credit
# 13                                          No credit
# 14                                          No credit
# 15                                          No credit
# 16                                          No credit
# 17                                          No credit
# 18                                          No credit
# 19                                          No credit
# 20                                          No credit
# 21                                          No credit
# 22                                          No credit
# 23                                          No credit
# 24                                          No credit
# 25                                          No credit
# 26                                          No credit
# 27                                          No credit
# 28                                GENYA SAVILOV / AFP
# 29                                                 AP
# 30                                MARTIN LELIEVRE/AFP
# 31                              Alister Doyle/REUTERS
# 32                   Markus Mainka/imageBROKER/MAXPPP
# 33  Courtesy Galerie Buchholz, Berlin, Galerie Cha...
# 34                                          No credit
# 35                                          No credit
# 36                                          No credit
# 37                                          No credit
# 38                                          No credit
# 39                                          No credit
# 40                                          No credit
# 41                                          No credit
# 42                                          No credit
# 43                                          No credit
# 44                                          No credit
# 45                                          No credit
# 46                                          No credit
# 47                                          No credit
# 48                                          No credit
# 49                                          No credit
# 50                                          No credit
# 51                                          No credit
# 52                                          No credit
#
#                                              Subtitle            Access  \
# 0                                         No subtitle      Free to read
# 1                                         No subtitle  Subscribers only
# 2                                         No subtitle  Subscribers only
# 3                                         No subtitle  Subscribers only
# 4                                         No subtitle      Free to read
# 5                                         No subtitle  Subscribers only
# 6                                         No subtitle  Subscribers only
# 7                                         No subtitle  Subscribers only
# 8                                         No subtitle  Subscribers only
# 9                                         No subtitle  Subscribers only
# 10                                        No subtitle  Subscribers only
# 11                                        No subtitle  Subscribers only
# 12                                        No subtitle      Free to read
# 13                                        No subtitle      Free to read
# 14                                        No subtitle  Subscribers only
# 15                                        No subtitle      Free to read
# 16                                        No subtitle  Subscribers only
# 17                                        No subtitle      Free to read
# 18                                        No subtitle  Subscribers only
# 19                                        No subtitle  Subscribers only
# 20                                        No subtitle  Subscribers only
# 21                                        No subtitle  Subscribers only
# 22                                        No subtitle  Subscribers only
# 23                                        No subtitle  Subscribers only
# 24                                        No subtitle  Subscribers only
# 25                                        No subtitle  Subscribers only
# 26                                        No subtitle  Subscribers only
# 27                                        No subtitle  Subscribers only
# 28  'The Transatlantic Divorce' (5/5). After Barac...  Subscribers only
# 29                                        No subtitle      Free to read
# 30                                        No subtitle  Subscribers only
# 31  While residents of the Scandinavian country – ...  Subscribers only
# 32  After high-speed rail, subway lines are now dr...  Subscribers only
# 33  Ever since his start in the 1980s, the world-r...  Subscribers only
# 34  The current wave of targeted assassinations ha...  Subscribers only
# 35                                        No subtitle      Free to read
# 36                                        No subtitle      Free to read
# 37                                        No subtitle  Subscribers only
# 38                                        No subtitle  Subscribers only
# 39                                        No subtitle      Free to read
# 40                                        No subtitle      Free to read
# 41                                        No subtitle  Subscribers only
# 42                                        No subtitle      Free to read
# 43                                        No subtitle  Subscribers only
# 44                                        No subtitle  Subscribers only
# 45                                        No subtitle      Free to read
# 46                                        No subtitle  Subscribers only
# 47  According to a group of scientists, the target...  Subscribers only
# 48  A study by the French Institute of Internation...  Subscribers only
# 49  The building designed by Renzo Piano and Richa...  Subscribers only
# 50                                        No subtitle         Subscribe
# 51                                        No subtitle         Subscribe
# 52                                        No subtitle      Free to read
#
#                 Type
# 0              World
# 1              World
# 2              World
# 3              World
# 4             Europe
# 5              World
# 6              World
# 7              World
# 8             France
# 9             France
# 10           Culture
# 11            France
# 12            Videos
# 13            Videos
# 14            Videos
# 15            Videos
# 16           Opinion
# 17         Editorial
# 18           Opinion
# 19           Opinion
# 20          Magazine
# 21          Magazine
# 22          Magazine
# 23          Magazine
# 24           Opinion
# 25           Culture
# 26         Lifestyle
# 27           Culture
# 28  Type not labeled
# 29  Type not labeled
# 30  Type not labeled
# 31  Type not labeled
# 32  Type not labeled
# 33  Type not labeled
# 34  Type not labeled
# 35  Type not labeled
# 36  Type not labeled
# 37  Type not labeled
# 38  Type not labeled
# 39  Type not labeled
# 40  Type not labeled
# 41  Type not labeled
# 42  Type not labeled
# 43  Type not labeled
# 44  Type not labeled
# 45  Type not labeled
# 46  Type not labeled
# 47  Type not labeled
# 48  Type not labeled
# 49  Type not labeled
# 50  Type not labeled
# 51  Type not labeled
# 52  Type not labeled

# %%
df.to_csv("news.csv", index=False)
